# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshafirdose31/Cognizant_AI/blob/main/Cognizant_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# And now we can import this package like so:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import datetime as dt
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline 
sns.set(color_codes=True)
import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")
# Out:
# <ipython-input-3-82af5e0edb29>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime as dt

# %% [markdown]
# ---
#
# ## Section 2 - Data loading
#
# Now that Google Drive is mounted, you can store the CSV file anywhere in your Drive and update the `path` variable below to access it within this notebook. Once we've updated the `path`, let's read this CSV file into a pandas dataframe and see what it looks like

# %%
path = "/content/drive/MyDrive/sample_sales_data.csv"
df = pd.read_csv(path)
df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
df.head()
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %% [markdown]
# ---
#
# ## Section 3 - Descriptive statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB

# %%
df.describe()
# Out:
#         unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000
# mean      7.819480     2.501597    19.709905
# std       5.388088     1.122722    17.446680
# min       0.190000     1.000000     0.190000
# 25%       3.990000     1.000000     6.570000
# 50%       7.190000     3.000000    14.970000
# 75%      11.190000     4.000000    28.470000
# max      23.990000     4.000000    95.960000

# %%
df.shape
# Out:
# (7829, 9)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7824    False
# 7825    False
# 7826    False
# 7827    False
# 7828    False
# Length: 7829, dtype: bool

# %%
df.isnull().sum()
# Out:
# transaction_id    0
# timestamp         0
# product_id        0
# category          0
# customer_type     0
# unit_price        0
# quantity          0
# total             0
# payment_type      0
# dtype: int64

# %%
# Extracting Date,Year,Month,Day
df.timestamp = pd.to_datetime(df.timestamp)

# %%
df['day'] = df.timestamp.dt.day_name() # Thanks @Mark Wang
df['year'] = df.timestamp.dt.year
df['month'] = df.timestamp.dt.month

# %%
df.drop(["product_id"],axis=1,inplace=True)
df.drop(["transaction_id"],axis=1,inplace=True)

# %%
df.drop(["timestamp"],axis=1,inplace=True)

# %% [markdown]
# # Checking Unique Values

# %%
df["day"].unique()
# Out:
# array(['Wednesday', 'Sunday', 'Friday', 'Saturday', 'Monday', 'Tuesday',
#        'Thursday'], dtype=object)

# %%
df["day"].unique()
# Out:
# array(['Wednesday', 'Sunday', 'Friday', 'Saturday', 'Monday', 'Tuesday',
#        'Thursday'], dtype=object)

# %%
df["year"].unique()
# Out:
# array([2022])

# %%
df["customer_type"].unique()
# Out:
# array(['gold', 'standard', 'premium', 'basic', 'non-member'], dtype=object)

# %%
df["category"].unique()
# Out:
# array(['fruit', 'vegetables', 'refrigerated items', 'frozen',
#        'spices and herbs', 'canned foods', 'packaged foods',
#        'condiments and sauces', 'beverages', 'dairy', 'cheese', 'meat',
#        'seafood', 'baked goods', 'baking', 'snacks', 'baby products',
#        'pets', 'personal care', 'medicine', 'kitchen',
#        'cleaning products'], dtype=object)

# %%
df["payment_type"].unique()
# Out:
# array(['e-wallet', 'debit card', 'cash', 'credit card'], dtype=object)

# %% [markdown]
# ---
#
# ## Section 4 - Visualisation
#
# Now that you've computed some descriptive statistics of the dataset, let's create some visualisations. You may use any package that you wish for visualisation, however, some helper functions have been provided that make use of the `seaborn` package. If you wish to use these helper functions, ensure to run the below cells that install and import `seaborn`.

# %%
# !pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import seaborn as sns

# %% [markdown]
# To analyse the dataset, below are snippets of code that you can use as helper functions to visualise different columns within the dataset. They include:
#
# - plot_continuous_distribution = this is to visualise the distribution of numeric columns
# - get_unique_values = this is to show how many unique values are present within a column
# - plot_categorical_distribution = this is to visualise the distribution of categorical columns
# - correlation_plot = this is to plot the correlations between the numeric columns within the data

# %%
df.head()
# Out:
#   category customer_type  unit_price  quantity  total payment_type        day  \
# 0    fruit          gold        3.99         2   7.98     e-wallet  Wednesday
# 1    fruit      standard        3.99         1   3.99     e-wallet     Sunday
# 2    fruit       premium        0.19         2   0.38     e-wallet     Friday
# 3    fruit          gold        0.19         4   0.76     e-wallet  Wednesday
# 4    fruit         basic        4.49         2   8.98   debit card   Saturday
#
#    year  month
# 0  2022      3
# 1  2022      3
# 2  2022      3
# 3  2022      3
# 4  2022      3

# %%
df['customer_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7829 entries, 0 to 7828
# Series name: customer_type
# Non-Null Count  Dtype
# --------------  -----
# 7829 non-null   object
# dtypes: object(1)
# memory usage: 61.3+ KB

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = None):
  corr = df.corr()
  corr.style.background_gradient(cmap='coolwarm')

# %% [markdown]
# ###**plot_continuous_distribution** function is useful for numerical columns. Let's find the which are the numerical columns in our dataset and their distribution.

# %%
plot_continuous_distribution(df, 'unit_price')

# %% [markdown]
# ### The plot of the continuous unit price distribution appears to be skewed to the right, i.e. more data points are clustered to the left and the right end is longer. This means that items with a lower unit price (cheaper items) sell more than expensive items.

# %%
plot_continuous_distribution(df, 'quantity')

# %% [markdown]
# ###The graph of the continuous distribution of the quantity appears to be uniformly distributed and has 4 different values ​​(1, 2, 3, 4). This means that the same amount of products are sold in all 4 values.

# %%
plot_continuous_distribution(df, 'total')

# %% [markdown]
# ###The continuous distribution diagram of the **total** purchase appears to be perfectly skewed, which is consistent with the unit price. This means that customers usually make smaller transactions and occasionally make larger transactions.

# %% [markdown]
# # Univariate Analysis.

# %%
df["customer_type"].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='customer_type'>

# %% [markdown]
# ##Here we can see that the percentage of Non-Members are more followed by Standard members, and Premium members, so we can increase the sale by offering coupons to them to attract the customers with benefits compared to other stores.

# %%
plot_categorical_distribution(df, 'payment_type')

# %% [markdown]
# ### From the above inference we may say that the payment type that the customers prefer at our store is **cash** followed by **credit card** compared to **e-wallet** or **debit card**.

# %% [markdown]
# #Bi-Variate

# %% [markdown]
# ###Top 3 Contributors with respect to their category.

# %%
plt.figure(figsize=(20,5))
ax=sns.barplot(x=list(df.groupby('category').sum().sort_values(by='unit_price',ascending=False).index),
               y=list(df.groupby('category').sum().sort_values(by='unit_price',ascending=False).iloc[:,2]),
               data=df,palette='Paired')
ax.set_xticklabels(ax.get_xticklabels(),rotation=40)
plt.show()
print(df.groupby('category').sum()['total'].sort_values(ascending=False).head(3))
# Out:
# category
# kitchen    14456.65
# meat       14102.31
# seafood    10754.81
# Name: total, dtype: float64

# %% [markdown]
# ###**Inference**: The **kitchen, meat and medicine** contribute highest sale at our store and we may also include the latest items to our list so to attract our customers.

# %% [markdown]
# ### Customers and their payment type

# %%
room_type_pref = sns.catplot(data=df,x='payment_type',kind='count',col='customer_type', palette='icefire_r')

# %% [markdown]
# ###Inference:
# Premium Customers: Prefer Cash followed by debit card
#
# Gold Customers: Prefer e-waller followed by credit card
#
# Standard Customers: Prefer cash followed by credit card
#
# Basic Customers: Prefer debit card
#
# Non-Member: Prefer cash or debit_card

# %% [markdown]
# ###Total Sales per category

# %%
import matplotlib.pyplot as plt

# Define a list of colors for each category
colors = ['purple', 'blue', 'green', 'orange', 'red', "black",'pink','maroon','brown','violet']

# Generate the bar plot with multiple colors
df.groupby('category')['total'].mean().plot(kind='barh', color=colors)

# Add title and labels
plt.title('Total Sales per category')
plt.xlabel('category')
plt.ylabel('total')

# Display the plot
plt.show()

# %% [markdown]
# ### Here we can see total sales by each category.

# %% [markdown]
# ##Daily Sales Data

# %%
sns.lineplot(x= df.groupby(df.day).mean().index, 
             y = df.groupby(df.day).mean()['total'])
# Out:
# <Axes: xlabel='day', ylabel='total'>

# %% [markdown]
# ###**Inference**: We may say that the highest sale is on Saturdays,Thurdays and Fridays since the rest of the days are working days and people on sundays may go out for vacations,short trips or out of towns.

# %% [markdown]
# Quantity of each category.

# %%
plt.figure(figsize=(20,5))
ax=sns.barplot(x='category',y='quantity',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40)
plt.show()
print(df.groupby('category').max()['quantity'].sort_values(ascending=False).head(3))
# Out:
# category
# baby products       4
# baked goods         4
# spices and herbs    4
# Name: quantity, dtype: int64

# %% [markdown]
# ###Inference: We may say that the highest quantites present at our store are Seafoods, Cheese, Personal Care, Dairy.

# %% [markdown]
# # Multi-Variate

# %%
plt.figure(figsize=(80, 30))  # Adjust the width and height as desired

# Create the grouped bar plot
sns.barplot(x='category', y='unit_price', hue='day', data=df)

# Add title and display the plot
plt.title('Grouped Bar Plot')
plt.show()

# %% [markdown]
# Here we may see that, Seafood, Frozen items and beverages quantity is huge at our store compared to rest, since the meat and seafoods are the highest profitable items.

# %%
per_df=pd.concat([df, pd.get_dummies(df['day'])],axis=1) ## One-Hot Encoding Day columns

# %%
per_df.head(5)
# Out:
#   category customer_type  unit_price  quantity  total payment_type        day  \
# 0    fruit          gold        3.99         2   7.98     e-wallet  Wednesday
# 1    fruit      standard        3.99         1   3.99     e-wallet     Sunday
# 2    fruit       premium        0.19         2   0.38     e-wallet     Friday
# 3    fruit          gold        0.19         4   0.76     e-wallet  Wednesday
# 4    fruit         basic        4.49         2   8.98   debit card   Saturday
#
#    year  month  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# 0  2022      3       0       0         0       0         0        0          1
# 1  2022      3       0       0         0       1         0        0          0
# 2  2022      3       1       0         0       0         0        0          0
# 3  2022      3       0       0         0       0         0        0          1
# 4  2022      3       0       0         1       0         0        0          0

# %%
for i in range(len(per_df['total'])):
    per_df['Wednesday'][i]=per_df['total'][i] * per_df.loc[:,"Wednesday"][i]
    per_df['Thursday'][i]=per_df['total'][i] * per_df.loc[:,"Thursday"][i]
    per_df['Friday'][i]=per_df['total'][i] * per_df.loc[:,"Friday"][i]
    per_df['Saturday'][i]=per_df['total'][i] * per_df.loc[:,"Saturday"][i]
    per_df['Sunday'][i]=per_df['total'][i] * per_df.loc[:,"Sunday"][i]
    per_df['Monday'][i]=per_df['total'][i] * per_df.loc[:,"Monday"][i]
    per_df['Tuesday'][i]=per_df['total'][i] * per_df.loc[:,"Tuesday"][i]

# %%
Daily_df=pd.DataFrame(per_df.groupby('category').sum()[['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']])

# %%
Daily_df
# Out:
#                         Sunday   Monday  Tuesday  Wednesday  Thursday  \
# category
# baby products           801.34  1148.86   973.03    1011.17    927.43
# baked goods            1357.14   870.10  1363.06    1314.48   1323.64
# baking                  621.12   417.37   633.51     436.45    603.00
# beverages              1522.09  1110.33  1453.18    1278.58   1838.79
# canned foods           1010.93   825.25  1007.46    1070.20   1019.03
# cheese                  621.95  1115.63   931.87    1161.08    746.56
# cleaning products      1449.91  1351.02   915.97    1419.72   1663.03
# condiments and sauces   522.61   364.89   539.47     537.36    363.81
# dairy                   986.32  1120.53  1122.02    1213.68    904.94
# frozen                 1029.30   880.28   895.45    1099.75    918.65
# fruit                   780.60   741.63   916.00     995.16    770.72
# kitchen                2129.01  2357.04  2078.35    1775.92   1530.95
# ...

# %%
for i in range(len(Daily_df.columns)):
    plt.figure(figsize=(20,5))
    ax=sns.barplot(x=Daily_df.index,y=Daily_df.iloc[:,i],data=Daily_df,palette='Set1')
    ax.set_xticklabels(ax.get_xticklabels(),rotation=50)
    plt.title("Top Selling category in each Day")
    plt.show()

# %% [markdown]
# #Section 5 - Summary
# We have completed an initial exploratory data analysis on the sample of data provided. We should now have a solid understanding of the data.
#
# ###Conclusion:
#
# * We can increase the sale by offering coupons to them to attract the customers with benefits compared to other stores, since we have non-mmbers percent high at our store when compared to regular customers
# * We can increase the kitchen, meat, seafood inventories to attract customers as these are high selling at our store.
# * Highest sale is on Saturdays, Thursdays and Fridays since the rest of the days are working days and people on sundays may go out for vacations,short trips or out of towns, so we can give them promotional ads on Sundays to increase the sale 2x.
# * the highest quantites present at our store are Seafoods, Cheese, Personal Care, Dairy as these are daily essentials and cutomers may visit often to buy daily essentials products so that we may group the type of customers easily based on their tastes.
# * Also we may say that the customers prefer cash, credit or debit card as a payment method.
# * Since its a week data, we can see the trend that the quantities must be increased weekly and promotional offers must be given until the sales profit becomes high.
# * By examining transaction data, EDA enables Gala Store to understand which products are frequently purchased together. This information can be used to implement cross-selling or upselling strategies, enhance product placement, and improve the overall shopping experience.
# * Also we can take feedback from customers about their experience at our store to enchance the overall performance at store and to derive much insights from the feedback given.
# * Also by checking customers preferences from data this knowledge allows Gala Store to align its product assortment and marketing efforts with customer preferences, improving customer satisfaction and driving repeat business.
